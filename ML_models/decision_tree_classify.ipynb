# %%
import numpy as np
import pandas as pd
#import cv2
import os
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from skimage.transform import resize
from skimage.io import imread
from sklearn.metrics import ConfusionMatrixDisplay

# %%
Categories=['NORMAL','PNEUMONIA']

# %%
def load_image(datadir, Categories):

    flat_data_arr=[]
    target_arr=[]

    for i in Categories:

        print(f'loading... category : {i}')
        path=os.path.join(datadir,i)
        for img in os.listdir(path):
            img_array=imread(os.path.join(path,img))
            img_resized=resize(img_array,(150,150,3))
            flat_data_arr.append(img_resized.flatten())
            target_arr.append(Categories.index(i))
        print(f'loaded category:{i} successfully')

    flat_data=np.array(flat_data_arr)
    target=np.array(target_arr)

    df=pd.DataFrame(flat_data)
    df['Target']=target

    x=df.iloc[:,:-1]
    y=df.iloc[:,-1]
    return x, y

# %%
datadir = 'D:/github/archive/chest_xray/train'
X, y = load_image(datadir, Categories)
# Out:
# loading... category : NORMAL
# loaded category:NORMAL successfully
# loading... category : PNEUMONIA
# loaded category:PNEUMONIA successfully

# %%
datadir2 = 'D:/github/archive/chest_xray/test'
X_test2, y_test2 = load_image(datadir2, Categories)
# Out:
# loading... category : NORMAL
# loaded category:NORMAL successfully
# loading... category : PNEUMONIA
# loaded category:PNEUMONIA successfully

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
decision_tree = tree.DecisionTreeClassifier()

# %%
decision_tree.fit(X_train, y_train)

print("Decision Tree Accuracy Score: ", decision_tree.score(X_test, y_test))
# Out:
# Decision Tree Accuracy Score:  0.8773162939297124

# %%
tree.plot_tree(decision_tree)
# Out:
# [Text(0.6304311497326203, 0.9857142857142858, 'x[66150] <= 0.0\ngini = 0.377\nsamples = 3651\nvalue = [921, 2730]'),
#  Text(0.39087566844919786, 0.9571428571428572, 'x[210] <= 0.771\ngini = 0.496\nsamples = 1400\nvalue = [760, 640]'),
#  Text(0.16243315508021391, 0.9285714285714286, 'x[765] <= 0.102\ngini = 0.452\nsamples = 802\nvalue = [277, 525]'),
#  Text(0.0427807486631016, 0.9, 'x[62626] <= 0.464\ngini = 0.245\nsamples = 105\nvalue = [90, 15]'),
#  Text(0.03208556149732621, 0.8714285714285714, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.053475935828877004, 0.8714285714285714, 'x[43376] <= 0.695\ngini = 0.134\nsamples = 97\nvalue = [90, 7]'),
#  Text(0.0427807486631016, 0.8428571428571429, 'x[26707] <= 0.525\ngini = 0.081\nsamples = 94\nvalue = [90, 4]'),
#  Text(0.03208556149732621, 0.8142857142857143, 'x[9145] <= 0.878\ngini = 0.043\nsamples = 92\nvalue = [90, 2]'),
#  Text(0.0213903743315508, 0.7857142857142857, 'x[7331] <= 0.111\ngini = 0.022\nsamples = 91\nvalue = [90, 1]'),
#  Text(0.0106951871657754, 0.7571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03208556149732621, 0.7571428571428571, 'gini = 0.0\nsamples = 90\nvalue = [90, 0]'),
#  Text(0.0427807486631016, 0.7857142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.053475935828877004, 0.8142857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06417112299465241, 0.8428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2820855614973262, 0.9, 'x[49772] <= 0.637\ngini = 0.393\nsamples = 697\nvalue = [187, 510]'),
#  Text(0.17379679144385027, 0.8714285714285714, 'x[62038] <= 0.493\ngini = 0.5\nsamples = 277\nvalue = [136, 141]'),
#  Text(0.12032085561497326, 0.8428571428571429, 'x[57081] <= 0.464\ngini = 0.325\nsamples = 137\nvalue = [28, 109]'),
#  Text(0.09090909090909091, 0.8142857142857143, 'x[32110] <= 0.242\ngini = 0.209\nsamples = 118\nvalue = [14, 104]'),
#  Text(0.06417112299465241, 0.7857142857142857, 'x[45330] <= 0.619\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.053475935828877004, 0.7571428571428571, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.0748663101604278, 0.7571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11764705882352941, 0.7857142857142857, 'x[2022] <= 0.712\ngini = 0.134\nsamples = 111\nvalue = [8, 103]'),
#  Text(0.0962566844919786, 0.7571428571428571, 'x[1898] <= 0.0\ngini = 0.02\nsamples = 98\nvalue = [1, 97]'),
#  Text(0.0855614973262032, 0.7285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10695187165775401, 0.7285714285714285, 'gini = 0.0\nsamples = 97\nvalue = [0, 97]'),
#  Text(0.13903743315508021, 0.7571428571428571, 'x[11719] <= 0.21\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.12834224598930483, 0.7285714285714285, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.1497326203208556, 0.7285714285714285, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.1497326203208556, 0.8142857142857143, 'x[54998] <= 0.53\ngini = 0.388\nsamples = 19\nvalue = [14, 5]'),
#  Text(0.13903743315508021, 0.7857142857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.16042780748663102, 0.7857142857142857, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.22727272727272727, 0.8428571428571429, 'x[57678] <= 0.475\ngini = 0.353\nsamples = 140\nvalue = [108, 32]'),
#  Text(0.1925133689839572, 0.8142857142857143, 'x[53162] <= 0.5\ngini = 0.42\nsamples = 30\nvalue = [9, 21]'),
#  Text(0.18181818181818182, 0.7857142857142857, 'x[34539] <= 0.222\ngini = 0.159\nsamples = 23\nvalue = [2, 21]'),
#  Text(0.1711229946524064, 0.7571428571428571, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1925133689839572, 0.7571428571428571, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.20320855614973263, 0.7857142857142857, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.2620320855614973, 0.8142857142857143, 'x[33448] <= 0.47\ngini = 0.18\nsamples = 110\nvalue = [99, 11]'),
#  Text(0.23529411764705882, 0.7857142857142857, 'x[49365] <= 0.663\ngini = 0.076\nsamples = 101\nvalue = [97, 4]'),
#  Text(0.21390374331550802, 0.7571428571428571, 'x[13120] <= 0.086\ngini = 0.02\nsamples = 97\nvalue = [96, 1]'),
#  Text(0.20320855614973263, 0.7285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22459893048128343, 0.7285714285714285, 'gini = 0.0\nsamples = 96\nvalue = [96, 0]'),
#  Text(0.25668449197860965, 0.7571428571428571, 'x[16726] <= 0.51\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.24598930481283424, 0.7285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26737967914438504, 0.7285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2887700534759358, 0.7857142857142857, 'x[38299] <= 0.605\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.27807486631016043, 0.7571428571428571, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.2994652406417112, 0.7571428571428571, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.39037433155080214, 0.8714285714285714, 'x[64980] <= 0.854\ngini = 0.213\nsamples = 420\nvalue = [51, 369]'),
#  Text(0.36363636363636365, 0.8428571428571429, 'x[1146] <= 0.848\ngini = 0.128\nsamples = 364\nvalue = [25, 339]'),
#  Text(0.35294117647058826, 0.8142857142857143, 'x[1085] <= 0.842\ngini = 0.101\nsamples = 358\nvalue = [19, 339]'),
#  Text(0.3422459893048128, 0.7857142857142857, 'x[5239] <= 0.826\ngini = 0.081\nsamples = 354\nvalue = [15, 339]'),
#  Text(0.32085561497326204, 0.7571428571428571, 'x[1431] <= 0.0\ngini = 0.061\nsamples = 349\nvalue = [11, 338]'),
#  Text(0.31016042780748665, 0.7285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3315508021390374, 0.7285714285714285, 'x[61983] <= 0.833\ngini = 0.045\nsamples = 346\nvalue = [8, 338]'),
#  Text(0.32085561497326204, 0.7, 'x[14707] <= 0.841\ngini = 0.034\nsamples = 344\nvalue = [6, 338]'),
#  Text(0.31016042780748665, 0.6714285714285714, 'x[2942] <= 0.408\ngini = 0.023\nsamples = 342\nvalue = [4, 338]'),
#  Text(0.2887700534759358, 0.6428571428571429, 'x[4839] <= 0.435\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.27807486631016043, 0.6142857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2994652406417112, 0.6142857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3315508021390374, 0.6428571428571429, 'x[42306] <= 0.192\ngini = 0.012\nsamples = 339\nvalue = [2, 337]'),
#  Text(0.32085561497326204, 0.6142857142857143, 'x[5612] <= 0.366\ngini = 0.006\nsamples = 338\nvalue = [1, 337]'),
#  Text(0.31016042780748665, 0.5857142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3315508021390374, 0.5857142857142857, 'gini = 0.0\nsamples = 337\nvalue = [0, 337]'),
#  Text(0.3422459893048128, 0.6142857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3315508021390374, 0.6714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3422459893048128, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.36363636363636365, 0.7571428571428571, 'x[6750] <= 0.308\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.35294117647058826, 0.7285714285714285, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.37433155080213903, 0.7285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36363636363636365, 0.7857142857142857, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.37433155080213903, 0.8142857142857143, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.41711229946524064, 0.8428571428571429, 'x[42474] <= 0.609\ngini = 0.497\nsamples = 56\nvalue = [26, 30]'),
#  Text(0.39572192513368987, 0.8142857142857143, 'x[10855] <= 0.246\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.3850267379679144, 0.7857142857142857, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.40641711229946526, 0.7857142857142857, 'x[53197] <= 0.242\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.39572192513368987, 0.7571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41711229946524064, 0.7571428571428571, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.4385026737967914, 0.8142857142857143, 'x[6590] <= 0.837\ngini = 0.074\nsamples = 26\nvalue = [1, 25]'),
#  Text(0.42780748663101603, 0.7857142857142857, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(0.44919786096256686, 0.7857142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6193181818181818, 0.9285714285714286, 'x[45272] <= 0.725\ngini = 0.311\nsamples = 598\nvalue = [483, 115]'),
#  Text(0.5487967914438503, 0.9, 'x[59776] <= 0.336\ngini = 0.17\nsamples = 489\nvalue = [443, 46]'),
#  Text(0.4919786096256685, 0.8714285714285714, 'x[48949] <= 0.323\ngini = 0.484\nsamples = 39\nvalue = [16, 23]'),
#  Text(0.47058823529411764, 0.8428571428571429, 'x[4618] <= 0.565\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.45989304812834225, 0.8142857142857143, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.48128342245989303, 0.8142857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5133689839572193, 0.8428571428571429, 'x[67273] <= 0.885\ngini = 0.26\nsamples = 26\nvalue = [4, 22]'),
#  Text(0.5026737967914439, 0.8142857142857143, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]'),
#  Text(0.5240641711229946, 0.8142857142857143, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6056149732620321, 0.8714285714285714, 'x[64352] <= 0.0\ngini = 0.097\nsamples = 450\nvalue = [427, 23]'),
#  Text(0.5748663101604278, 0.8428571428571429, 'x[21892] <= 0.637\ngini = 0.07\nsamples = 442\nvalue = [426, 16]'),
#  Text(0.5454545454545454, 0.8142857142857143, 'x[55464] <= 0.274\ngini = 0.049\nsamples = 436\nvalue = [425, 11]'),
#  Text(0.5187165775401069, 0.7857142857142857, 'x[57389] <= 0.724\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5080213903743316, 0.7571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5294117647058824, 0.7571428571428571, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5721925133689839, 0.7857142857142857, 'x[33822] <= 0.203\ngini = 0.032\nsamples = 431\nvalue = [424, 7]'),
#  Text(0.5508021390374331, 0.7571428571428571, 'x[42722] <= 0.028\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5401069518716578, 0.7285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5614973262032086, 0.7285714285714285, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5935828877005348, 0.7571428571428571, 'x[5535] <= 0.89\ngini = 0.023\nsamples = 428\nvalue = [423, 5]'),
#  Text(0.5828877005347594, 0.7285714285714285, 'x[4378] <= 0.845\ngini = 0.019\nsamples = 427\nvalue = [423, 4]'),
#  Text(0.5721925133689839, 0.7, 'x[54786] <= 0.065\ngini = 0.014\nsamples = 426\nvalue = [423, 3]'),
#  Text(0.5614973262032086, 0.6714285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5828877005347594, 0.6714285714285714, 'x[61652] <= 0.027\ngini = 0.009\nsamples = 425\nvalue = [423, 2]'),
#  Text(0.5721925133689839, 0.6428571428571429, 'x[51223] <= 0.735\ngini = 0.005\nsamples = 424\nvalue = [423, 1]'),
#  Text(0.5614973262032086, 0.6142857142857143, 'gini = 0.0\nsamples = 423\nvalue = [423, 0]'),
#  Text(0.5828877005347594, 0.6142857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5935828877005348, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5935828877005348, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6042780748663101, 0.7285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6042780748663101, 0.8142857142857143, 'x[8875] <= 0.443\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.5935828877005348, 0.7857142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6149732620320856, 0.7857142857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6363636363636364, 0.8428571428571429, 'x[41478] <= 0.512\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.6256684491978609, 0.8142857142857143, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6470588235294118, 0.8142857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6898395721925134, 0.9, 'x[23562] <= 0.451\ngini = 0.465\nsamples = 109\nvalue = [40, 69]'),
#  Text(0.6684491978609626, 0.8714285714285714, 'x[59769] <= 0.541\ngini = 0.38\nsamples = 47\nvalue = [35, 12]'),
#  Text(0.6577540106951871, 0.8428571428571429, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.679144385026738, 0.8428571428571429, 'x[1137] <= 0.647\ngini = 0.054\nsamples = 36\nvalue = [35, 1]'),
#  Text(0.6684491978609626, 0.8142857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6898395721925134, 0.8142857142857143, 'gini = 0.0\nsamples = 35\nvalue = [35, 0]'),
#  Text(0.7112299465240641, 0.8714285714285714, 'x[35810] <= 0.678\ngini = 0.148\nsamples = 62\nvalue = [5, 57]'),
#  Text(0.7005347593582888, 0.8428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7219251336898396, 0.8428571428571429, 'x[29488] <= 0.706\ngini = 0.034\nsamples = 58\nvalue = [1, 57]'),
#  Text(0.7112299465240641, 0.8142857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.732620320855615, 0.8142857142857143, 'gini = 0.0\nsamples = 57\nvalue = [0, 57]'),
#  Text(0.8699866310160428, 0.9571428571428572, 'x[245] <= 0.822\ngini = 0.133\nsamples = 2251\nvalue = [161, 2090]'),
#  Text(0.8094919786096256, 0.9285714285714286, 'x[301] <= 0.012\ngini = 0.087\nsamples = 2102\nvalue = [96, 2006]'),
#  Text(0.7780748663101604, 0.9, 'x[20886] <= 0.679\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.767379679144385, 0.8714285714285714, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.7887700534759359, 0.8714285714285714, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8409090909090909, 0.9, 'x[1612] <= 0.848\ngini = 0.073\nsamples = 2081\nvalue = [79, 2002]'),
#  Text(0.8101604278074866, 0.8714285714285714, 'x[14885] <= 0.81\ngini = 0.064\nsamples = 2070\nvalue = [69, 2001]'),
#  Text(0.7807486631016043, 0.8428571428571429, 'x[145] <= 0.049\ngini = 0.057\nsamples = 2059\nvalue = [60, 1999]'),
#  Text(0.7540106951871658, 0.8142857142857143, 'x[17837] <= 0.461\ngini = 0.444\nsamples = 42\nvalue = [14, 28]'),
#  Text(0.7433155080213903, 0.7857142857142857, 'x[26636] <= 0.346\ngini = 0.346\nsamples = 18\nvalue = [14, 4]'),
#  Text(0.732620320855615, 0.7571428571428571, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7540106951871658, 0.7571428571428571, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.7647058823529411, 0.7857142857142857, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.8074866310160428, 0.8142857142857143, 'x[3813] <= 0.838\ngini = 0.045\nsamples = 2017\nvalue = [46, 1971]'),
#  Text(0.786096256684492, 0.7857142857142857, 'x[67062] <= 0.82\ngini = 0.039\nsamples = 2007\nvalue = [40, 1967]'),
#  Text(0.7754010695187166, 0.7571428571428571, 'x[285] <= 0.101\ngini = 0.036\nsamples = 2004\nvalue = [37, 1967]'),
#  Text(0.7540106951871658, 0.7285714285714285, 'x[6807] <= 0.241\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.7433155080213903, 0.7, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7647058823529411, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7967914438502673, 0.7285714285714285, 'x[37298] <= 0.861\ngini = 0.033\nsamples = 1997\nvalue = [33, 1964]'),
#  Text(0.786096256684492, 0.7, 'x[11836] <= 0.883\ngini = 0.031\nsamples = 1995\nvalue = [31, 1964]'),
#  Text(0.7754010695187166, 0.6714285714285714, 'x[23312] <= 0.887\ngini = 0.029\nsamples = 1993\nvalue = [29, 1964]'),
#  Text(0.7647058823529411, 0.6428571428571429, 'x[65431] <= 0.945\ngini = 0.027\nsamples = 1991\nvalue = [27, 1964]'),
#  Text(0.7540106951871658, 0.6142857142857143, 'x[9564] <= 0.911\ngini = 0.025\nsamples = 1989\nvalue = [25, 1964]'),
#  Text(0.7433155080213903, 0.5857142857142857, 'x[6879] <= 0.881\ngini = 0.023\nsamples = 1987\nvalue = [23, 1964]'),
#  Text(0.732620320855615, 0.5571428571428572, 'x[173] <= 0.874\ngini = 0.021\nsamples = 1985\nvalue = [21, 1964]'),
#  Text(0.7112299465240641, 0.5285714285714286, 'x[21290] <= 0.787\ngini = 0.019\nsamples = 1982\nvalue = [19, 1963]'),
#  Text(0.7005347593582888, 0.5, 'x[10201] <= 0.897\ngini = 0.018\nsamples = 1981\nvalue = [18, 1963]'),
#  Text(0.6898395721925134, 0.4714285714285714, 'x[10641] <= 0.859\ngini = 0.017\nsamples = 1980\nvalue = [17, 1963]'),
#  Text(0.679144385026738, 0.44285714285714284, 'x[20817] <= 0.828\ngini = 0.016\nsamples = 1979\nvalue = [16, 1963]'),
#  Text(0.6684491978609626, 0.4142857142857143, 'x[26656] <= 0.913\ngini = 0.015\nsamples = 1978\nvalue = [15, 1963]'),
#  Text(0.6577540106951871, 0.38571428571428573, 'x[27543] <= 0.848\ngini = 0.014\nsamples = 1977\nvalue = [14, 1963]'),
#  Text(0.6470588235294118, 0.35714285714285715, 'x[171] <= 0.1\ngini = 0.013\nsamples = 1976\nvalue = [13, 1963]'),
#  Text(0.6149941510695187, 0.32857142857142857, 'x[9746] <= 0.605\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6042989639037433, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6256893382352942, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6791234959893048, 0.32857142857142857, 'x[7350] <= 0.881\ngini = 0.012\nsamples = 1974\nvalue = [12, 1962]'),
#  Text(0.6470797125668449, 0.3, 'x[33693] <= 0.87\ngini = 0.011\nsamples = 1972\nvalue = [11, 1961]'),
#  Text(0.6150777072192514, 0.2714285714285714, 'x[48904] <= 0.188\ngini = 0.01\nsamples = 1970\nvalue = [10, 1960]'),
#  Text(0.5831592580213903, 0.24285714285714285, 'x[35851] <= 0.275\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.572464070855615, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5938544451871658, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6469961564171123, 0.24285714285714285, 'x[749] <= 0.066\ngini = 0.009\nsamples = 1967\nvalue = [9, 1958]'),
#  Text(0.6152448195187166, 0.21428571428571427, 'x[17576] <= 0.322\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6045496323529411, 0.18571428571428572, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.625940006684492, 0.18571428571428572, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.678747493315508, 0.21428571428571427, 'x[58844] <= 0.156\ngini = 0.008\nsamples = 1963\nvalue = [8, 1955]'),
#  Text(0.6473303810160428, 0.18571428571428572, 'x[21899] <= 0.442\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6366351938502673, 0.15714285714285714, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6580255681818182, 0.15714285714285714, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7101646056149733, 0.18571428571428572, 'x[32103] <= 0.183\ngini = 0.007\nsamples = 1958\nvalue = [7, 1951]'),
#  Text(0.679415942513369, 0.15714285714285714, 'x[34391] <= 0.553\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.6687207553475936, 0.12857142857142856, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.6901111296791443, 0.12857142857142856, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7409132687165776, 0.15714285714285714, 'x[5705] <= 0.174\ngini = 0.005\nsamples = 1936\nvalue = [5, 1931]'),
#  Text(0.7115015040106952, 0.12857142857142856, 'x[26804] <= 0.609\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.7008063168449198, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.7221966911764706, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.77032503342246, 0.12857142857142856, 'x[1083] <= 0.797\ngini = 0.004\nsamples = 1928\nvalue = [4, 1924]'),
#  Text(0.7435870655080213, 0.1, 'x[1165] <= 0.807\ngini = 0.002\nsamples = 1879\nvalue = [2, 1877]'),
#  Text(0.7221966911764706, 0.07142857142857142, 'x[149] <= 0.134\ngini = 0.001\nsamples = 1861\nvalue = [1, 1860]'),
#  Text(0.7115015040106952, 0.04285714285714286, 'x[26603] <= 0.651\ngini = 0.064\nsamples = 30\nvalue = [1, 29]'),
#  Text(0.7008063168449198, 0.014285714285714285, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(0.7221966911764706, 0.014285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.732891878342246, 0.04285714285714286, 'gini = 0.0\nsamples = 1831\nvalue = [0, 1831]'),
#  Text(0.7649774398395722, 0.07142857142857142, 'x[39430] <= 0.677\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(0.7542822526737968, 0.04285714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7756726270053476, 0.04285714285714286, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.7970630013368984, 0.1, 'x[43898] <= 0.718\ngini = 0.078\nsamples = 49\nvalue = [2, 47]'),
#  Text(0.786367814171123, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8077581885026738, 0.07142857142857142, 'gini = 0.0\nsamples = 47\nvalue = [0, 47]'),
#  Text(0.6790817179144385, 0.2714285714285714, 'x[20481] <= 0.704\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.668386530748663, 0.24285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6897769050802139, 0.24285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7111672794117647, 0.3, 'x[29029] <= 0.804\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7004720922459893, 0.2714285714285714, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.72186246657754, 0.2714285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6684491978609626, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.679144385026738, 0.38571428571428573, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6898395721925134, 0.4142857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7005347593582888, 0.44285714285714284, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7112299465240641, 0.4714285714285714, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7219251336898396, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7540106951871658, 0.5285714285714286, 'x[41648] <= 0.826\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7433155080213903, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7647058823529411, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7540106951871658, 0.5571428571428572, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7647058823529411, 0.5857142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7754010695187166, 0.6142857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.786096256684492, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7967914438502673, 0.6714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8074866310160428, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7967914438502673, 0.7571428571428571, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8288770053475936, 0.7857142857142857, 'x[48826] <= 0.788\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.8181818181818182, 0.7571428571428571, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.839572192513369, 0.7571428571428571, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.839572192513369, 0.8428571428571429, 'x[30435] <= 0.751\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.8288770053475936, 0.8142857142857143, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.8502673796791443, 0.8142857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8716577540106952, 0.8714285714285714, 'x[22716] <= 0.787\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.8609625668449198, 0.8428571428571429, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.8823529411764706, 0.8428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.93048128342246, 0.9285714285714286, 'x[45272] <= 0.703\ngini = 0.492\nsamples = 149\nvalue = [65, 84]'),
#  Text(0.9037433155080213, 0.9, 'x[34159] <= 0.0\ngini = 0.07\nsamples = 55\nvalue = [53, 2]'),
#  Text(0.893048128342246, 0.8714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9144385026737968, 0.8714285714285714, 'gini = 0.0\nsamples = 53\nvalue = [53, 0]'),
#  Text(0.9572192513368984, 0.9, 'x[7325] <= 0.58\ngini = 0.223\nsamples = 94\nvalue = [12, 82]'),
#  Text(0.9358288770053476, 0.8714285714285714, 'x[13008] <= 0.188\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.9251336898395722, 0.8428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.946524064171123, 0.8428571428571429, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.9786096256684492, 0.8714285714285714, 'x[55969] <= 0.907\ngini = 0.092\nsamples = 83\nvalue = [4, 79]'),
#  Text(0.9679144385026738, 0.8428571428571429, 'x[66126] <= 0.714\ngini = 0.025\nsamples = 80\nvalue = [1, 79]'),
#  Text(0.9572192513368984, 0.8142857142857143, 'gini = 0.0\nsamples = 79\nvalue = [0, 79]'),
#  Text(0.9786096256684492, 0.8142857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9893048128342246, 0.8428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %%
print("Decision Tree Accuracy Score using test data: ", decision_tree.score(X_test2, y_test2))
# Out:
# Decision Tree Accuracy Score using test data:  0.7403846153846154

# %%
y_pred = decision_tree.predict(X_test)
y_pred2 = decision_tree.predict(X_test2)

# %%
cm1 = confusion_matrix(y_pred, y_test)
ConfusionMatrixDisplay(confusion_matrix=cm1, display_labels=Categories).plot()

# %%
cm2 = confusion_matrix(y_pred2, y_test2)
ConfusionMatrixDisplay(confusion_matrix=cm2, display_labels=Categories).plot()

# %%
print("Classification Report using the splitted test data: ")
print(classification_report(y_test, y_pred, target_names=Categories))
# Out:
# Classification Report using the splitted test data:
#               precision    recall  f1-score   support
#
#       NORMAL       0.77      0.78      0.77       420
#    PNEUMONIA       0.92      0.91      0.92      1145
#
#     accuracy                           0.88      1565
#    macro avg       0.84      0.85      0.84      1565
# weighted avg       0.88      0.88      0.88      1565

# %%
print("Classification Report using the original test data: ")
print(classification_report(y_test2, y_pred2, target_names=Categories))
# Out:
# Classification Report using the original test data:
#               precision    recall  f1-score   support
#
#       NORMAL       0.86      0.37      0.51       234
#    PNEUMONIA       0.72      0.96      0.82       390
#
#     accuracy                           0.74       624
#    macro avg       0.79      0.67      0.67       624
# weighted avg       0.77      0.74      0.71       624
